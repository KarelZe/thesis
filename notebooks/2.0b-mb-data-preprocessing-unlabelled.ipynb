# %%
import sys
import os

import gcsfs
import numpy as np
import pandas as pd
import wandb
from catboost import CatBoostClassifier, Pool
from numpy.testing import assert_almost_equal
from pandas._testing.asserters import assert_almost_equal
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_predict
# from tqdm.notebook import tqdm

sys.path.append("..")

# %%
exchange = "ise"
strategy =  "unsupervised"
max_i = 30 # number of partial files

# %%
# connect to weights and biases
run = wandb.init(project="thesis", job_type="dataset-creation", entity="fbv")
dataset = wandb.Artifact(name=f"{exchange}_{strategy}_raw", type="preprocessed_data")
# Out:
# Finishing last run (ID:clqncvl4) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">daily-tree-893</strong>: <a href="https://wandb.ai/fbv/thesis/runs/clqncvl4" target="_blank">https://wandb.ai/fbv/thesis/runs/clqncvl4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230328_233750-clqncvl4/logs</code>
# Successfully finished last run (ID:clqncvl4). Initializing new run:<br/>
# wandb version 0.14.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/pfs/data5/home/kit/stud/uloak/thesis/notebooks/wandb/run-20230329_003950-17j2ph98</code>
# Syncing run <strong><a href="https://wandb.ai/fbv/thesis/runs/17j2ph98" target="_blank">tough-bush-894</a></strong> to <a href="https://wandb.ai/fbv/thesis" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
os.environ["GCLOUD_PROJECT"] = "flowing-mantis-239216"

fs = gcsfs.GCSFileSystem(project="thesis")
# Out:
# /pfs/data5/home/kit/stud/uloak/thesis/thesis/lib/python3.8/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
files = [f"gs://thesis-bucket-option-trade-classification/data/preprocessed/{'matched' if strategy == 'supervised' else 'unmatched'}_{exchange}_quotes_min_mem_usage_extended_part_{i:04d}.parquet" for i in range(0, max_i)]

# asks = [f"ASK_{i}" for i in range(1, 17)]
# bids = [f"BID_{i}" for i in range(1, 17)]

columns = [
    "QUOTE_DATETIME",
    "ROOT",
    "EXPIRATION",
    "STRK_PRC",
    "OPTION_TYPE",
    "TRADE_SIZE",
    "TRADE_PRICE",
    "BEST_BID",
    "BEST_ASK",
    "ask_ex",
    "bid_ex",
    "bid_size_ex",
    "ask_size_ex",
    "price_all_lead",
    "price_all_lag",
    "optionid",
    # "day_vol",
    "price_ex_lead",
    "price_ex_lag",
    "issue_type",
    "myn",
    # *asks,
    # *bids,
    #"buy_sell",
]

dfs = [pd.read_parquet(gc_file, columns=columns) for gc_file in files]
df = pd.concat(dfs)

del dfs

# %%
df.memory_usage(deep=True).sum()
# Out:
# 4246414955

# %%
df.sort_values(by="QUOTE_DATETIME", inplace=True)

# %%
# There are a few duplicates in the unlabelled dataset, removed see p. 7

subset = ['QUOTE_DATETIME', 'ROOT',
         'OPTION_TYPE', 'EXPIRATION', 'STRK_PRC', 
       'TRADE_SIZE', 'TRADE_PRICE', 'BEST_BID', 'BEST_ASK', 'ask_ex', 'bid_ex',
       'bid_size_ex', 'ask_size_ex', 
       # FIXME is different for loballed and unlabelled trades
       # 'optionid','issue_type', 'myn', 
       # 'price_all_lead', 'price_all_lag',
       # 'price_ex_lead', 'price_ex_lag', 
       ]

# df.drop_duplicates(keep='first', subset=subset, inplace=True)

# %%
# FIXME: replace with generic name
columns = ["buy_sell", *df.columns.tolist()]
labelled_df = pd.read_parquet("gs://thesis-bucket-option-trade-classification/data/preprocessed/train_set_ultra_60.parquet", columns=columns)

# %%
# slice labelled dataframe to range of unlabelled
date_range = labelled_df.QUOTE_DATETIME.between(df.QUOTE_DATETIME.min(), df.QUOTE_DATETIME.max())
labelled_df = labelled_df[date_range]

# %%
# labelled_df.drop_duplicates(keep='first', subset=subset, inplace=True)

# %%
labelled_df["duplicated"] = labelled_df.duplicated(subset=subset)

# %%
labelled_df[(labelled_df["QUOTE_DATETIME"]=="2012-10-24 09:30:14")  & (labelled_df["optionid"]==83414152.0)].head(20).T
# Out:
#                            25414881             25414882             25414885
# buy_sell                         -1                   -1                   -1
# QUOTE_DATETIME  2012-10-24 09:30:14  2012-10-24 09:30:14  2012-10-24 09:30:14
# ROOT                            CVX                  CVX                  CVX
# EXPIRATION      2013-06-22 00:00:00  2013-06-22 00:00:00  2013-06-22 00:00:00
# STRK_PRC                      100.0                100.0                100.0
# OPTION_TYPE                       P                    P                    P
# TRADE_SIZE                        5                    5                   40
# TRADE_PRICE                    4.35                 4.35                 4.32
# BEST_BID                       4.35                 4.35                 4.35
# BEST_ASK                        4.5                  4.5                  4.5
# ask_ex                          NaN                  NaN                  4.5
# bid_ex                          NaN                  NaN                  4.3
# bid_size_ex                     NaN                  NaN                 11.0
# ask_size_ex                     NaN                  NaN                 38.0
# price_all_lead                 4.32                 4.32                 4.55
# price_all_lag                  4.15                 4.15                 4.35
# optionid                 83414152.0           83414152.0           83414152.0
# price_ex_lead                  4.32                 4.32                 4.27
# price_ex_lag                    3.6                  3.6                 4.35
# issue_type                        0                    0                    0
# myn                        0.910622             0.910622             0.910622
# duplicated                    False                 True                False

# %%
len_labelled_df = len(labelled_df)
len_df = len(df)

# %%
# merge with indicator and find out which ones can be labelled
df_w_indicator = pd.merge(df, labelled_df, on=['QUOTE_DATETIME', 'ROOT', 
                                            'OPTION_TYPE', 
                                            'EXPIRATION', 'STRK_PRC',
       'TRADE_SIZE', 'TRADE_PRICE', 'BEST_BID', 'BEST_ASK', 'ask_ex', 'bid_ex', 'bid_size_ex', 'ask_size_ex',
       # myn seems to be different
       #'issue_type', 'optionid',
       # 'price_all_lead', 'price_all_lag', # FIXME is different for loballed and unlabelled trades
       # 'price_ex_lead', 'price_ex_lag', # FIXME is different for loballed and unlabelled trades 
       ], how="left", indicator='exists', suffixes=("_unlabelled", "_labelled"), sort=True)

# %%
df_w_indicator["exists"].value_counts()
# Out:
# left_only     25746535
# both           4191137
# right_only           0
# Name: exists, dtype: int64

# %%
len(df_w_indicator)
# Out:
# 29937672

# %%
len(df)
# Out:
# 29842162

# %%
len(labelled_df)
# Out:
# 4095627

# %%
df_w_indicator.sort_index(axis=1, inplace=True)

# %%
df_w_indicator[df_w_indicator["exists"]=="both"].head(20).T
# Out:
#                                            0                    21   \
# BEST_ASK                                  0.75                  5.0
# BEST_BID                                   0.5                  4.6
# EXPIRATION                 2013-01-19 00:00:00  2012-12-22 00:00:00
# OPTION_TYPE                                  C                    C
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                      ALXN                  ERX
# STRK_PRC                                 125.0                 50.0
# TRADE_PRICE                               0.75                  4.6
# TRADE_SIZE                                   4                    1
# ask_ex                                    0.75                  5.0
# ask_size_ex                               11.0                 41.0
# bid_ex                                     0.5                  4.6
# bid_size_ex                               11.0                 20.0
# buy_sell                                   1.0                 -1.0
# exists                                    both                 both
# issue_type_labelled                          0                    %
# issue_type_unlabelled                        0                    %
# myn_labelled                             0.814               1.0043
# myn_unlabelled                           0.814               1.0043
# optionid_labelled                   81791240.0           83420560.0
# optionid_unlabelled                 81791240.0           83420560.0
# price_all_lag_labelled                     1.0                 4.25
# price_all_lag_unlabelled                   1.0                 4.25
# price_all_lead_labelled                   0.63                  4.0
# price_all_lead_unlabelled                 0.63                  4.0
# price_ex_lag_labelled                      1.0                  NaN
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     0.3                 4.42
# price_ex_lead_unlabelled                   0.3                 4.42
#
#                                            24                   61   \
# BEST_ASK                                   7.8                  0.0
# BEST_BID                                   7.5                  0.0
# EXPIRATION                 2012-10-26 00:00:00  2012-12-22 00:00:00
# OPTION_TYPE                                  C                    P
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                        FB                   FB
# STRK_PRC                                  16.5                 17.0
# TRADE_PRICE                               7.62                 0.25
# TRADE_SIZE                                  20                    1
# ask_ex                                     7.8                  NaN
# ask_size_ex                               10.0                  NaN
# bid_ex                                     7.5                  NaN
# bid_size_ex                               10.0                  NaN
# buy_sell                                  -1.0                  1.0
# exists                                    both                 both
# issue_type_labelled                          0                    0
# issue_type_unlabelled                        0                    0
# myn_labelled                          1.462121             0.707596
# myn_unlabelled                        1.462121             0.707596
# optionid_labelled                   83390144.0           81935280.0
# optionid_unlabelled                 83390144.0           81935280.0
# price_all_lag_labelled                     3.2                 0.91
# price_all_lag_unlabelled                   3.2                 0.91
# price_all_lead_labelled                    7.3                  0.2
# price_all_lead_unlabelled                  7.3                  0.2
# price_ex_lag_labelled                      3.3                 0.92
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     NaN                  0.2
# price_ex_lead_unlabelled                   NaN                  0.2
#
#                                            63                   65   \
# BEST_ASK                                   0.0                  0.3
# BEST_BID                                   0.0                 0.15
# EXPIRATION                 2013-01-19 00:00:00  2013-03-16 00:00:00
# OPTION_TYPE                                  P                    P
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                        FB                   FB
# STRK_PRC                                  16.0                 14.0
# TRADE_PRICE                               0.25                  0.3
# TRADE_SIZE                                  10                    1
# ask_ex                                     NaN                  0.3
# ask_size_ex                                NaN                 25.0
# bid_ex                                     NaN                 0.15
# bid_size_ex                                NaN                 25.0
# buy_sell                                   1.0                  1.0
# exists                                    both                 both
# issue_type_labelled                          0                    0
# issue_type_unlabelled                        0                    0
# myn_labelled                          0.665973              0.58007
# myn_unlabelled                        0.665973              0.58007
# optionid_labelled                   81935360.0           81935440.0
# optionid_unlabelled                 81935360.0           81935440.0
# price_all_lag_labelled                     0.8                  0.7
# price_all_lag_unlabelled                   0.8                  0.7
# price_all_lead_labelled                    0.2                 0.25
# price_all_lead_unlabelled                  0.2                 0.25
# price_ex_lag_labelled                      0.8                  0.7
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                    0.35                 0.47
# price_ex_lead_unlabelled                  0.35                 0.47
#
#                                            66                   83   \
# BEST_ASK                                  0.65                 0.25
# BEST_BID                                   0.5                  0.0
# EXPIRATION                 2013-03-16 00:00:00  2012-12-22 00:00:00
# OPTION_TYPE                                  P                    C
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                        FB                 IRBT
# STRK_PRC                                  17.0                 25.0
# TRADE_PRICE                               0.65                 0.25
# TRADE_SIZE                                  10                    4
# ask_ex                                    0.65                 0.25
# ask_size_ex                               10.0                 40.0
# bid_ex                                     0.5                  0.0
# bid_size_ex                               10.0                  0.0
# buy_sell                                   1.0                  1.0
# exists                                    both                 both
# issue_type_labelled                          0                    0
# issue_type_unlabelled                        0                    0
# myn_labelled                          0.704663               0.7746
# myn_unlabelled                        0.704663               0.7746
# optionid_labelled                   81935448.0           81741912.0
# optionid_unlabelled                 81935448.0           81741912.0
# price_all_lag_labelled                     1.6                 0.91
# price_all_lag_unlabelled                   1.6                 0.91
# price_all_lead_labelled                    0.7                 0.15
# price_all_lead_unlabelled                  0.7                 0.15
# price_ex_lag_labelled                      1.5                  0.8
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     0.8                  0.1
# price_ex_lead_unlabelled                   0.8                  0.1
#
#                                            127                  145  \
# BEST_ASK                                   0.0                 14.8
# BEST_BID                                   0.0                 10.2
# EXPIRATION                 2014-01-18 00:00:00  2014-01-18 00:00:00
# OPTION_TYPE                                  C                    P
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                      NFLX                 NFLX
# STRK_PRC                                  27.5                 55.0
# TRADE_PRICE                          33.700001                11.38
# TRADE_SIZE                                   1                    1
# ask_ex                                     NaN                 14.8
# ask_size_ex                                NaN                 10.0
# bid_ex                                     NaN                 10.2
# bid_size_ex                                NaN                  1.0
# buy_sell                                   1.0                 -1.0
# exists                                    both                 both
# issue_type_labelled                          0                    0
# issue_type_unlabelled                        0                    0
# myn_labelled                          2.070182             0.953041
# myn_unlabelled                        2.070182             0.953041
# optionid_labelled                   83081424.0           80929664.0
# optionid_unlabelled                 83081424.0           80929664.0
# price_all_lag_labelled               41.549999                 10.2
# price_all_lag_unlabelled             41.549999                 10.2
# price_all_lead_labelled              55.119999                 11.3
# price_all_lead_unlabelled            55.119999                 11.3
# price_ex_lag_labelled                      NaN                 10.2
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     NaN                 5.93
# price_ex_lead_unlabelled                   NaN                 5.93
#
#                                            146                  150  \
# BEST_ASK                                  0.35                  8.6
# BEST_BID                                  0.25                  8.1
# EXPIRATION                 2012-11-17 00:00:00  2012-11-17 00:00:00
# OPTION_TYPE                                  P                    C
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                       OIL                 QCOR
# STRK_PRC                                  20.0                 19.0
# TRADE_PRICE                               0.35                  8.1
# TRADE_SIZE                                  50                    1
# ask_ex                                    0.35                  8.6
# ask_size_ex                               50.0                 20.0
# bid_ex                                    0.25                  8.1
# bid_size_ex                               11.0                 31.0
# buy_sell                                  -1.0                 -1.0
# exists                                    both                 both
# issue_type_labelled                          %                    0
# issue_type_unlabelled                        %                    0
# myn_labelled                          0.962464             1.435526
# myn_unlabelled                        0.962464             1.435526
# optionid_labelled                   83305584.0           83335304.0
# optionid_unlabelled                 83305584.0           83335304.0
# price_all_lag_labelled                    0.45                  7.2
# price_all_lag_unlabelled                  0.45                  7.2
# price_all_lead_labelled                    0.4                  7.3
# price_all_lead_unlabelled                  0.4                  7.3
# price_ex_lag_labelled                      0.2                 7.26
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                    0.25                  NaN
# price_ex_lead_unlabelled                  0.25                  NaN
#
#                                            151                  152  \
# BEST_ASK                                   5.7                 0.55
# BEST_BID                                   5.2                  0.3
# EXPIRATION                 2013-01-19 00:00:00  2013-01-19 00:00:00
# OPTION_TYPE                                  C                    C
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                      QCOR                 QCOR
# STRK_PRC                                  24.0                 46.0
# TRADE_PRICE                                5.2                  0.3
# TRADE_SIZE                                  10                    1
# ask_ex                                     5.7                 0.55
# ask_size_ex                               10.0                 10.0
# bid_ex                                     5.2                  0.3
# bid_size_ex                               21.0                 10.0
# buy_sell                                  -1.0                 -1.0
# exists                                    both                 both
# issue_type_labelled                          0                    0
# issue_type_unlabelled                        0                    0
# myn_labelled                          1.136458             0.592935
# myn_unlabelled                        1.136458             0.592935
# optionid_labelled                   81922768.0           81898728.0
# optionid_unlabelled                 81922768.0           81898728.0
# price_all_lag_labelled                     5.1                  0.2
# price_all_lag_unlabelled                   5.1                  0.2
# price_all_lead_labelled                    4.3                 0.05
# price_all_lead_unlabelled                  4.3                 0.05
# price_ex_lag_labelled                     4.72                  5.8
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     2.7                  NaN
# price_ex_lead_unlabelled                   2.7                  NaN
#
#                                            153                  159  \
# BEST_ASK                                   0.0                 0.02
# BEST_BID                                   0.0                 0.01
# EXPIRATION                 2013-01-19 00:00:00  2012-10-26 00:00:00
# OPTION_TYPE                                  C                    P
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                      QCOR                  QQQ
# STRK_PRC                                  47.0                 60.0
# TRADE_PRICE                               0.25                 0.01
# TRADE_SIZE                                   2                    4
# ask_ex                                     NaN                 0.02
# ask_size_ex                                NaN                602.0
# bid_ex                                     NaN                 0.01
# bid_size_ex                                NaN                  4.0
# buy_sell                                  -1.0                  1.0
# exists                                    both                 both
# issue_type_labelled                          0                    %
# issue_type_unlabelled                        0                    %
# myn_labelled                          0.555319             0.912617
# myn_unlabelled                        0.555319             0.912617
# optionid_labelled                   81898728.0           83393416.0
# optionid_unlabelled                 81898728.0           83393416.0
# price_all_lag_labelled                     0.3                 0.02
# price_all_lag_unlabelled                   0.3                 0.02
# price_all_lead_labelled                   0.15                  NaN
# price_all_lead_unlabelled                 0.15                  NaN
# price_ex_lag_labelled                     1.75                 0.02
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     NaN                  NaN
# price_ex_lead_unlabelled                   NaN                  NaN
#
#                                            163                  164  \
# BEST_ASK                                   0.0                  0.0
# BEST_BID                                   0.0                  0.0
# EXPIRATION                 2013-01-19 00:00:00  2013-01-19 00:00:00
# OPTION_TYPE                                  P                    C
# QUOTE_DATETIME             2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                                       UCO                  XLK
# STRK_PRC                                  34.0                 33.0
# TRADE_PRICE                                7.9                 0.05
# TRADE_SIZE                                   2                    1
# ask_ex                                     NaN                  NaN
# ask_size_ex                                NaN                  NaN
# bid_ex                                     NaN                  NaN
# bid_size_ex                                NaN                  NaN
# buy_sell                                  -1.0                  1.0
# exists                                    both                 both
# issue_type_labelled                          %                    %
# issue_type_unlabelled                        %                    %
# myn_labelled                          1.240876             0.887576
# myn_unlabelled                        1.240876             0.887576
# optionid_labelled                   81825568.0           65911088.0
# optionid_unlabelled                 81825568.0           65911088.0
# price_all_lag_labelled                    6.17                 0.06
# price_all_lag_unlabelled                  6.17                 0.06
# price_all_lead_labelled                    8.0                 0.02
# price_all_lead_unlabelled                  8.0                 0.02
# price_ex_lag_labelled                     5.58                 0.06
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                     4.1                 0.01
# price_ex_lead_unlabelled                   4.1                 0.01
#
#                                            184                  185
# BEST_ASK                                   1.7                 4.65
# BEST_BID                                   1.6                  4.5
# EXPIRATION                 2013-04-20 00:00:00  2013-04-20 00:00:00
# OPTION_TYPE                                  P                    P
# QUOTE_DATETIME             2012-10-24 09:30:01  2012-10-24 09:30:01
# ROOT                                      EBAY                 EBAY
# STRK_PRC                                  42.0                 50.0
# TRADE_PRICE                               1.62                 4.61
# TRADE_SIZE                                   2                    2
# ask_ex                                    1.72                 4.65
# ask_size_ex                               28.0                 57.0
# bid_ex                                    1.56                  4.5
# bid_size_ex                               28.0                 57.0
# buy_sell                                  -1.0                  1.0
# exists                                    both                 both
# issue_type_labelled                          0                    0
# issue_type_unlabelled                        0                    0
# myn_labelled                          0.849085             1.010816
# myn_unlabelled                        0.849085             1.010816
# optionid_labelled                   83122224.0           83122232.0
# optionid_unlabelled                 83122224.0           83122232.0
# price_all_lag_labelled                     1.6                 4.35
# price_all_lag_unlabelled                   1.6                 4.35
# price_all_lead_labelled                   1.85                  4.8
# price_all_lead_unlabelled                 1.85                  4.8
# price_ex_lag_labelled                     2.41                 4.35
# price_ex_lag_unlabelled                    NaN                  NaN
# price_ex_lead_labelled                    1.85                  4.9
# price_ex_lead_unlabelled                  1.85                  4.9

# %%
# add fields
df_w_indicator["buy_sell"] = 0

# %%
df_w_indicator["day_vol"] = df_w_indicator.groupby([df_w_indicator['QUOTE_DATETIME'].dt.date, df_w_indicator['optionid_unlabelled']])['TRADE_SIZE'].transform('sum')

# %%
df_w_indicator
# Out:
#           BEST_ASK  BEST_BID EXPIRATION OPTION_TYPE      QUOTE_DATETIME  ROOT  \
# 0             0.75      0.50 2013-01-19           C 2012-10-24 09:30:00  ALXN
# 1             0.00      0.00 2013-02-16           C 2012-10-24 09:30:00  ALXN
# 2             0.00      0.00 2012-11-17           P 2012-10-24 09:30:00  ALXN
# 3             0.00      0.00 2013-01-19           P 2012-10-24 09:30:00  ALXN
# 4             0.00      0.00 2013-05-18           P 2012-10-24 09:30:00  ALXN
# ...            ...       ...        ...         ...                 ...   ...
# 29937667      2.20      2.18 2013-12-21           C 2013-10-24 16:14:36   QQQ
# 29937668      2.20      2.18 2013-12-21           C 2013-10-24 16:14:36   QQQ
# 29937669      2.20      2.18 2013-12-21           C 2013-10-24 16:14:36   QQQ
# 29937670      2.20      2.18 2013-12-21           C 2013-10-24 16:14:36   QQQ
# 29937671      0.24      0.22 2013-10-25           P 2013-10-24 16:14:48   IWM
#
#           STRK_PRC  TRADE_PRICE  TRADE_SIZE  ask_ex  ...  optionid_unlabelled  \
# 0            125.0         0.75           4    0.75  ...           81791240.0
# 1            125.0         1.55          10     NaN  ...           82265992.0
# 2             80.0         0.35          10     NaN  ...           81567600.0
# 3             90.0         3.20          10     NaN  ...           81708440.0
# 4             60.0         1.20          10     NaN  ...           83336664.0
# ...            ...          ...         ...     ...  ...                  ...
# 29937667      82.0         2.18           5    2.21  ...          100511416.0
# 29937668      82.0         2.18           5    2.21  ...          100511416.0
# 29937669      82.0         2.18          10    2.21  ...          100511416.0
# 29937670      82.0         2.18          14    2.21  ...          100511416.0
# 29937671     111.0         0.24           5    0.24  ...          101650048.0
#
#           price_all_lag_labelled  price_all_lag_unlabelled  \
# 0                            1.0                      1.00
# 1                            NaN                      6.60
# 2                            NaN                      0.65
# 3                            NaN                      3.65
# 4                            NaN                      1.35
# ...                          ...                       ...
# 29937667                     NaN                      2.20
# 29937668                     NaN                      2.20
# 29937669                     NaN                      2.20
# 29937670                     NaN                      2.20
# 29937671                     NaN                      0.23
#
#           price_all_lead_labelled price_all_lead_unlabelled  \
# 0                            0.63                      0.63
# 1                             NaN                      0.50
# 2                             NaN                      0.52
# 3                             NaN                      3.80
# 4                             NaN                      1.25
# ...                           ...                       ...
# 29937667                      NaN                      2.25
# 29937668                      NaN                      2.25
# 29937669                      NaN                      2.25
# 29937670                      NaN                      2.25
# 29937671                      NaN                      0.15
#
#          price_ex_lag_labelled price_ex_lag_unlabelled  \
# 0                          1.0                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 29937667                   NaN                    2.20
# 29937668                   NaN                    2.20
# 29937669                   NaN                    2.20
# 29937670                   NaN                    2.20
# 29937671                   NaN                    0.23
#
#           price_ex_lead_labelled  price_ex_lead_unlabelled  day_vol
# 0                            0.3                      0.30     31.0
# 1                            NaN                      0.16     10.0
# 2                            NaN                      0.30    522.0
# 3                            NaN                      3.80     23.0
# 4                            NaN                      1.25     20.0
# ...                          ...                       ...      ...
# 29937667                     NaN                       NaN   3864.0
# 29937668                     NaN                       NaN   3864.0
# 29937669                     NaN                       NaN   3864.0
# 29937670                     NaN                       NaN   3864.0
# 29937671                     NaN                       NaN   4955.0
#
# [29937672 rows x 30 columns]

# %%
train = df_w_indicator[df_w_indicator["exists"]=="left_only"].drop(columns=['issue_type_labelled', 'myn_labelled',  'optionid_labelled', 'price_all_lag_labelled', 'price_all_lead_labelled', 'price_ex_lag_labelled', 'price_ex_lead_labelled', "exists"])
train.columns = train.columns.str.replace(r'_unlabelled$', '')
# Out:
# /scratch/slurm_tmpdir/job_21960101/ipykernel_236567/2426663307.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train.columns = train.columns.str.replace(r'_unlabelled$', '')

# %%
train.head().T
# Out:
#                                   1                    2                    3  \
# BEST_ASK                        0.0                  0.0                  0.0
# BEST_BID                        0.0                  0.0                  0.0
# EXPIRATION      2013-02-16 00:00:00  2012-11-17 00:00:00  2013-01-19 00:00:00
# OPTION_TYPE                       C                    P                    P
# QUOTE_DATETIME  2012-10-24 09:30:00  2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                           ALXN                 ALXN                 ALXN
# STRK_PRC                      125.0                 80.0                 90.0
# TRADE_PRICE                    1.55                 0.35                  3.2
# TRADE_SIZE                       10                   10                   10
# ask_ex                          NaN                  NaN                  NaN
# ask_size_ex                     NaN                  NaN                  NaN
# bid_ex                          NaN                  NaN                  NaN
# bid_size_ex                     NaN                  NaN                  NaN
# buy_sell                          0                    0                    0
# issue_type                        0                    0                    0
# myn                         0.81404             0.786241             0.884477
# optionid                 82265992.0           81567600.0           81708440.0
# price_all_lag                   6.6                 0.65                 3.65
# price_all_lead                  0.5                 0.52                  3.8
# price_ex_lag                    NaN                  NaN                  NaN
# price_ex_lead                  0.16                  0.3                  3.8
# day_vol                        10.0                522.0                 23.0
#
#                                   4                    5
# BEST_ASK                        0.0                 1.25
# BEST_BID                        0.0                  1.2
# EXPIRATION      2013-05-18 00:00:00  2013-05-18 00:00:00
# OPTION_TYPE                       P                    P
# QUOTE_DATETIME  2012-10-24 09:30:00  2012-10-24 09:30:00
# ROOT                           ALXN                 ALXN
# STRK_PRC                       60.0                 60.0
# TRADE_PRICE                     1.2                 1.25
# TRADE_SIZE                       10                   10
# ask_ex                          NaN                 1.25
# ask_size_ex                     NaN                 12.0
# bid_ex                          NaN                  1.2
# bid_size_ex                     NaN                  7.0
# buy_sell                          0                    0
# issue_type                        0                    0
# myn                        0.589681             0.589681
# optionid                 83336664.0           83336664.0
# price_all_lag                  1.35                  1.2
# price_all_lead                 1.25                  1.2
# price_ex_lag                    NaN                  1.2
# price_ex_lead                  1.25                  1.6
# day_vol                        20.0                 20.0

# %%
output_path = f"gs://thesis-bucket-option-trade-classification/data/preprocessed/{exchange}_{strategy}_train.parquet"
train.to_parquet(output_path)
dataset.add_reference(output_path, name="train_set")
# Out:
# /pfs/data5/home/kit/stud/uloak/thesis/thesis/lib/python3.8/site-packages/google/auth/_default.py:78: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# [<ManifestEntry ref: gs://thesis-bucket-option-trade-classification/data/preprocessed/ise_unsupervised_train.parquet/train_set>]

# %%
# Log the artifact to save it as an output of this run
run.log_artifact(dataset)
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# Synced <strong style="color:#cdcd00">tough-bush-894</strong>: <a href="https://wandb.ai/fbv/thesis/runs/17j2ph98" target="_blank">https://wandb.ai/fbv/thesis/runs/17j2ph98</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20230329_003950-17j2ph98/logs</code>
