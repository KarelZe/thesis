# %% [markdown]
# Run on runpods.io due to memory requirements. ⚠️

# %%
import os
import random

from catboost import CatBoostClassifier


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import cross_validate

from typing import List, Optional, Tuple

# %%
# set fixed seed
def seed_everything(seed) -> None:
    """
    Seeds basic parameters for reproducibility of results.
    """
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    # pandas and numpy as discussed here: https://stackoverflow.com/a/52375474/5755604
    np.random.seed(seed)


seed = 42
seed_everything(seed)

# %% [markdown]
# # Cross-validation⛑️

# %%
oe_option_type = OrdinalEncoder(
    unknown_value=-1, dtype=int, handle_unknown="use_encoded_value"
)
oe_root = OrdinalEncoder(
    unknown_value=-1, dtype=int, handle_unknown="use_encoded_value"
)
oe_issue_type = OrdinalEncoder(
    unknown_value=-1, dtype=int, handle_unknown="use_encoded_value"
)

# %%
def transform(data: pd.DataFrame) -> Tuple[pd.DataFrame, pd.Series]:

    # date features
    x = pd.DataFrame(
        data={"date_year": data["QUOTE_DATETIME"].dt.year}, index=data.index
    )

    x["date_month_sin"] = np.sin(2 * np.pi * data["QUOTE_DATETIME"].dt.year / 12)
    x["date_month_cos"] = np.cos(2 * np.pi * data["QUOTE_DATETIME"].dt.year / 12)

    seconds_in_day = 24 * 60 * 60
    seconds = (
        data["QUOTE_DATETIME"] - data["QUOTE_DATETIME"].dt.normalize()
    ).dt.total_seconds()

    x["date_time_sin"] = np.sin(2 * np.pi * seconds / seconds_in_day)
    x["date_time_cos"] = np.cos(2 * np.pi * seconds / seconds_in_day)

    # option features
    x["ttm"] = (
        data["EXPIRATION"].dt.to_period("M") - data["QUOTE_DATETIME"].dt.to_period("M")
    ).apply(lambda x: x.n)
    x[["myn", "day_vol"]] = data[["myn", "day_vol"]]
    # FIXME: make consistent later
    x["log_strk_prc"] = np.log1p(data["STRK_PRC"])

    # binarize
    # "bin_OPTION_TYPE", "bin_issue_type", "bin_ROOT",

    # size features
    x["bid_ask_size_ratio_ex"] = data["bid_size_ex"] / data["ask_size_ex"]
    x["rel_bid_size_ex"] = data["TRADE_SIZE"] / data["bid_size_ex"]
    x["rel_ask_size_ex"] = data["TRADE_SIZE"] / data["ask_size_ex"]
    x[["TRADE_SIZE", "bid_size_ex", "ask_size_ex"]] = data[
        ["TRADE_SIZE", "bid_size_ex", "ask_size_ex"]
    ]

    # classical
    mid_ex = 0.5 * (data["ask_ex"] + data["bid_ex"])
    mid_best = 0.5 * (data["BEST_ASK"] + data["BEST_BID"])
    x["rel_ask_ex"] = (data["TRADE_PRICE"] - mid_ex) / (data["ask_ex"] - mid_ex)
    x["rel_bid_ex"] = (mid_ex - data["TRADE_PRICE"]) / (mid_ex - data["bid_ex"])
    x["BEST_rel_bid"] = (data["TRADE_PRICE"] - mid_best) / (data["BEST_ASK"] - mid_best)
    x["BEST_rel_ask"] = (mid_best - data["TRADE_PRICE"]) / (mid_best - data["BEST_BID"])
    x["bid_ask_ratio_ex"] = data["bid_ex"] / data["ask_ex"]

    x["chg_ex_lead"] = data["TRADE_PRICE"] - data["price_ex_lead"]
    x["chg_ex_lag"] = data["TRADE_PRICE"] - data["price_ex_lag"]
    x["chg_all_lead"] = data["TRADE_PRICE"] - data["price_all_lead"]
    x["chg_all_lag"] = data["TRADE_PRICE"] - data["price_all_lag"]

    # no transform
    x[
        [
                "ask_ex",
                "bid_ex",
                "BEST_ASK",
                "BEST_BID",
                "TRADE_PRICE",
                "price_all_lag",
                "price_all_lead",
                "price_ex_lag",
                "price_ex_lead",
                "TRADE_SIZE",
                "bid_size_ex",
                "ask_size_ex",
        ]
    ] = data[
            [
                "ask_ex",
                "bid_ex",
                "BEST_ASK",
                "BEST_BID",
                "TRADE_PRICE",
                "price_all_lag",
                "price_all_lead",
                "price_ex_lag",
                "price_ex_lead",
                "TRADE_SIZE",
                "bid_size_ex",
                "ask_size_ex",
            ]
    ]


    # log(x + 0.01)
    x[
        [
            "log001p_ask_ex",
            "log001p_bid_ex",
            "log001p_BEST_ASK",
            "log001p_BEST_BID",
            "log001p_trade_price",
            "log001p_price_all_lag",
            "log001p_price_all_lead",
            "log001p_price_ex_lag",
            "log001p_price_ex_lead",
            "log001p_TRADE_SIZE",
            "log001p_bid_size_ex",
            "log001p_ask_size_ex",
        ]
    ] = np.log(
        data[
            [
                "ask_ex",
                "bid_ex",
                "BEST_ASK",
                "BEST_BID",
                "TRADE_PRICE",
                "price_all_lag",
                "price_all_lead",
                "price_ex_lag",
                "price_ex_lead",
                "TRADE_SIZE",
                "bid_size_ex",
                "ask_size_ex",
            ]
        ]
        + 1e-2
    )

    # log(x + 1)
    x[
        [
            "log1p_ask_ex",
            "log1p_bid_ex",
            "log1p_BEST_ASK",
            "log1p_BEST_BID",
            "log1p_trade_price",
            "log1p_price_all_lag",
            "log1p_price_all_lead",
            "log1p_price_ex_lag",
            "log1p_price_ex_lead",
            "log1p_TRADE_SIZE",
            "log1p_bid_size_ex",
            "log1p_ask_size_ex",
        ]
    ] = np.log1p(
        data[
            [
                "ask_ex",
                "bid_ex",
                "BEST_ASK",
                "BEST_BID",
                "TRADE_PRICE",
                "price_all_lag",
                "price_all_lead",
                "price_ex_lag",
                "price_ex_lead",
                "TRADE_SIZE",
                "bid_size_ex",
                "ask_size_ex",
            ]
        ]
    )

    # https://stackoverflow.com/questions/70727291/how-do-i-know-whether-a-sklearn-scaler-is-already-fitted-or-not

    if not hasattr(oe_option_type, "n_features_in_"):
        oe_option_type.fit(data["OPTION_TYPE"].astype(str).values.reshape(-1, 1))
    x["bin_option_type"] = oe_option_type.transform(
        data["OPTION_TYPE"].astype(str).values.reshape(-1, 1)
    )

    if not hasattr(oe_root, "n_features_in_"):
        oe_root.fit(data["ROOT"].astype(str).values.reshape(-1, 1))
    x["bin_root"] = oe_root.transform(data["ROOT"].astype(str).values.reshape(-1, 1))

    if not hasattr(oe_issue_type, "n_features_in_"):
        oe_issue_type.fit(data["issue_type"].astype(str).values.reshape(-1, 1))
    x["bin_issue_type"] = oe_issue_type.transform(
        data["issue_type"].astype(str).values.reshape(-1, 1)
    )

    x.replace([np.inf, -np.inf], np.nan, inplace=True)
    # fill all na with 0
    x.fillna(0, inplace=True)
    y = data["buy_sell"]
    return x, y

# %%
train = pd.read_parquet(
    "gs://thesis-bucket-option-trade-classification/data/preprocessed/train_set_extended_60.parquet"
)
x_train, y_train = transform(train)

del train
# Out:
# /usr/lib/python3/dist-packages/google/auth/_default.py:66: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
val = pd.read_parquet(
    "gs://thesis-bucket-option-trade-classification/data/preprocessed/val_set_extended_20.parquet"
)
x_val, y_val = transform(val)

del val

# %%
test = pd.read_parquet(
    "gs://thesis-bucket-option-trade-classification/data/preprocessed/test_set_extended_20.parquet"
)
x_test, y_test = transform(test)

del test

# %%
classical_features_log001p = [
    "BEST_rel_bid",
    "BEST_rel_ask",
    "rel_ask_ex",
    "rel_bid_ex",
    "bid_ask_ratio_ex",
    "log001p_ask_ex",
    "log001p_bid_ex",
    "log001p_BEST_ASK",
    "log001p_BEST_BID",
    "chg_ex_lag",
    "chg_ex_lead",
    "chg_all_lag",
    "chg_all_lead",
    "log001p_trade_price",
    "log001p_price_all_lag",
    "log001p_price_all_lead",
    "log001p_price_ex_lag",
    "log001p_price_ex_lead",
]

classical_features_log1p = [
    "BEST_rel_bid",
    "BEST_rel_ask",
    "rel_ask_ex",
    "rel_bid_ex",
    "bid_ask_ratio_ex",
    "log1p_ask_ex",
    "log1p_bid_ex",
    "log1p_BEST_ASK",
    "log1p_BEST_BID",
    "chg_ex_lag",
    "chg_ex_lead",
    "chg_all_lag",
    "chg_all_lead",
    "log1p_trade_price",
    "log1p_price_all_lag",
    "log1p_price_all_lead",
    "log1p_price_ex_lag",
    "log1p_price_ex_lead",
]

classical_features_no_transform = [
    "BEST_rel_bid",
    "BEST_rel_ask",
    "rel_ask_ex",
    "rel_bid_ex",
    "bid_ask_ratio_ex",
    "ask_ex",
    "bid_ex",
    "BEST_ASK",
    "BEST_BID",
    "chg_ex_lag",
    "chg_ex_lead",
    "chg_all_lag",
    "chg_all_lead",
    "TRADE_PRICE",
    "price_all_lag",
    "price_all_lead",
    "price_ex_lag",
    "price_ex_lead",
]


size_features_no_transform = [
    "TRADE_SIZE",
    "bid_ask_size_ratio_ex",
    "rel_bid_size_ex",
    "rel_ask_size_ex",
    "bid_size_ex",
    "ask_size_ex",
]

size_features_log001p= [
    "log001p_TRADE_SIZE",
    "bid_ask_size_ratio_ex",
    "rel_bid_size_ex",
    "rel_ask_size_ex",
    "log001p_bid_size_ex",
    "log001p_ask_size_ex",
]


size_features_log1p= [
    "log1p_TRADE_SIZE",
    "bid_ask_size_ratio_ex",
    "rel_bid_size_ex",
    "rel_ask_size_ex",
    "log1p_bid_size_ex",
    "log1p_ask_size_ex",
]

# %%
def evaluate(
    features: List[str], cat_features: Optional[List[str]]
) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:

    params = {
        "od_type": "Iter",
        "logging_level": "Silent",
        "depth": 8,
        "loss_function": "Logloss",
        "task_type": "GPU",
        "cat_features": cat_features,
        "random_seed": 42,
    }

    res = cross_validate(
        CatBoostClassifier(**params),
        x_train[features],
        y_train,
        cv=3,
        return_estimator=True,
    )
    results_cv = pd.DataFrame(res["test_score"], columns=["test_score_cv"])
    print(res)

    oos = []
    feature_importances = []
    for i, model in enumerate(res["estimator"]):

        oos.append(
            [
                i,
                model.score(x_train[features], y_train),
                model.score(x_val[features], y_val),
                model.score(x_test[features], y_test),
            ]
        )

        feature_importance = model.get_feature_importance(prettified=True).add_prefix(
            f"fold_{i}_"
        )
        feature_importances.append(feature_importance)

    results_oos = pd.DataFrame(
        data=oos, columns=["fold", "acc_train", "acc_val", "acc_test"]
    )
    results_fi = pd.concat(feature_importances, axis=1)

    return results_cv, results_oos, results_fi

# %%
results_cv, results_oos, results_fi = evaluate(classical_features_no_transform, [])
# Out:
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# {'fit_time': array([101.83080363, 100.52312589, 100.34640288]), 'score_time': array([2.9326396 , 3.06439018, 2.83942509]), 'estimator': [<catboost.core.CatBoostClassifier object at 0x7f1906ade6d0>, <catboost.core.CatBoostClassifier object at 0x7f1904f8f910>, <catboost.core.CatBoostClassifier object at 0x7f1904f8f070>], 'test_score': array([0.74423658, 0.76255363, 0.75422062])}
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %%
results_cv
# Out:
#    test_score_cv
# 0       0.744237
# 1       0.762554
# 2       0.754221

# %%
results_oos
# Out:
#    fold  acc_train   acc_val  acc_test
# 0     0   0.760781  0.630504  0.621895
# 1     1   0.768801  0.626294  0.622492
# 2     2   0.768717  0.617139  0.605304

# %%
results_fi
# Out:
#    fold_0_Feature Id  fold_0_Importances fold_1_Feature Id  \
# 0         rel_ask_ex           22.990729  bid_ask_ratio_ex
# 1         rel_bid_ex           15.813432        rel_ask_ex
# 2   bid_ask_ratio_ex            9.893765        rel_bid_ex
# 3       BEST_rel_bid            9.480421      BEST_rel_ask
# 4       BEST_rel_ask            8.392970      BEST_rel_bid
# 5       chg_all_lead            7.629985          BEST_ASK
# 6        chg_all_lag            5.351401      chg_all_lead
# 7             ask_ex            3.579094            ask_ex
# 8           BEST_ASK            3.299194       chg_all_lag
# 9             bid_ex            2.691742    price_all_lead
# 10    price_all_lead            2.624995            bid_ex
# 11          BEST_BID            2.041380       TRADE_PRICE
# 12       TRADE_PRICE            1.523562          BEST_BID
# 13        chg_ex_lag            1.399473        chg_ex_lag
# 14       chg_ex_lead            1.231283     price_ex_lead
# 15     price_ex_lead            1.106212       chg_ex_lead
# 16     price_all_lag            0.600706     price_all_lag
# 17      price_ex_lag            0.349659      price_ex_lag
#
#     fold_1_Importances fold_2_Feature Id  fold_2_Importances
# 0            19.897145        rel_ask_ex           19.172873
# 1            15.884092  bid_ask_ratio_ex           19.000829
# 2            15.421176        rel_bid_ex           16.397705
# 3             7.872446      BEST_rel_bid            7.884684
# 4             7.820222      BEST_rel_ask            7.689974
# 5             7.106836          BEST_ASK            7.639769
# 6             6.482494            ask_ex            5.098739
# 7             5.556844      chg_all_lead            4.643592
# 8             3.641820       chg_all_lag            2.595599
# 9             2.448944    price_all_lead            2.026251
# 10            1.801293            bid_ex            1.693231
# 11            1.321636       TRADE_PRICE            1.660674
# 12            1.310163        chg_ex_lag            1.497760
# 13            1.248209          BEST_BID            1.261377
# 14            0.817121     price_ex_lead            0.500135
# 15            0.723252       chg_ex_lead            0.461676
# 16            0.353916      price_ex_lag            0.430902
# 17            0.292391     price_all_lag            0.344228

# %%
results_cv, results_oos, results_fi = evaluate(classical_features_log001p, [])
# Out:
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# {'fit_time': array([101.43279958, 100.16543198,  99.77901578]), 'score_time': array([2.73329878, 2.88876295, 3.0164969 ]), 'estimator': [<catboost.core.CatBoostClassifier object at 0x7f1904fe4d60>, <catboost.core.CatBoostClassifier object at 0x7f17b8a7ef10>, <catboost.core.CatBoostClassifier object at 0x7f191417de80>], 'test_score': array([0.7445813 , 0.76267186, 0.75444579])}
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %%
results_cv
# Out:
#    test_score_cv
# 0       0.744581
# 1       0.762672
# 2       0.754446

# %%
results_oos
# Out:
#    fold  acc_train   acc_val  acc_test
# 0     0   0.760807  0.630140  0.621108
# 1     1   0.768993  0.625733  0.621746
# 2     2   0.768844  0.617210  0.605375

# %%
results_fi
# Out:
#          fold_0_Feature Id  fold_0_Importances       fold_1_Feature Id  \
# 0               rel_ask_ex           22.518260        bid_ask_ratio_ex
# 1               rel_bid_ex           16.590644              rel_ask_ex
# 2         bid_ask_ratio_ex           10.082350              rel_bid_ex
# 3             BEST_rel_bid            9.098977            BEST_rel_ask
# 4             BEST_rel_ask            8.888999            BEST_rel_bid
# 5             chg_all_lead            7.558550            chg_all_lead
# 6              chg_all_lag            5.381957        log001p_BEST_ASK
# 7           log001p_bid_ex            3.872086          log001p_ask_ex
# 8           log001p_ask_ex            3.610084             chg_all_lag
# 9         log001p_BEST_ASK            2.634967          log001p_bid_ex
# 10     log001p_trade_price            2.510005        log001p_BEST_BID
# 11        log001p_BEST_BID            2.186989              chg_ex_lag
# 12              chg_ex_lag            1.601340     log001p_trade_price
# 13             chg_ex_lead            1.601068             chg_ex_lead
# 14  log001p_price_all_lead            0.550841  log001p_price_all_lead
# 15   log001p_price_all_lag            0.530048   log001p_price_ex_lead
# 16   log001p_price_ex_lead            0.479838   log001p_price_all_lag
# 17    log001p_price_ex_lag            0.302998    log001p_price_ex_lag
#
#     fold_1_Importances       fold_2_Feature Id  fold_2_Importances
# 0            20.307738              rel_ask_ex           20.051904
# 1            16.330243        bid_ask_ratio_ex           19.261921
# 2            14.696587              rel_bid_ex           15.164447
# 3             8.074895            BEST_rel_ask            8.172676
# 4             7.546045            BEST_rel_bid            7.864983
# 5             6.673689        log001p_BEST_ASK            6.605035
# 6             6.652097          log001p_ask_ex            6.549743
# 7             6.265979            chg_all_lead            4.830204
# 8             3.480973          log001p_bid_ex            2.624055
# 9             3.015009             chg_all_lag            2.407413
# 10            1.691734              chg_ex_lag            1.568121
# 11            1.281507     log001p_trade_price            1.535978
# 12            1.266692        log001p_BEST_BID            1.123309
# 13            0.990535  log001p_price_all_lead            0.629352
# 14            0.724874             chg_ex_lead            0.579340
# 15            0.408878    log001p_price_ex_lag            0.407429
# 16            0.299082   log001p_price_ex_lead            0.351351
# 17            0.293443   log001p_price_all_lag            0.272739

# %%
results_cv, results_oos, results_fi = evaluate(classical_features_log1p, [])
# Out:
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# {'fit_time': array([101.30106139, 100.45461416,  99.7327745 ]), 'score_time': array([2.8108542 , 2.97966194, 2.71104765]), 'estimator': [<catboost.core.CatBoostClassifier object at 0x7f17af81d8e0>, <catboost.core.CatBoostClassifier object at 0x7f17af81dc10>, <catboost.core.CatBoostClassifier object at 0x7f1873daa8e0>], 'test_score': array([0.74417263, 0.76275502, 0.75427917])}
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %%
results_cv
# Out:
#    test_score_cv
# 0       0.744173
# 1       0.762755
# 2       0.754279

# %%
results_oos
# Out:
#    fold  acc_train   acc_val  acc_test
# 0     0   0.760689  0.630410  0.621853
# 1     1   0.768939  0.626289  0.622506
# 2     2   0.768755  0.617367  0.605534

# %%
results_fi
# Out:
#        fold_0_Feature Id  fold_0_Importances     fold_1_Feature Id  \
# 0             rel_ask_ex           22.992115      bid_ask_ratio_ex
# 1             rel_bid_ex           15.893097            rel_ask_ex
# 2       bid_ask_ratio_ex            9.850483            rel_bid_ex
# 3           BEST_rel_bid            9.511851          BEST_rel_bid
# 4           BEST_rel_ask            8.324598          BEST_rel_ask
# 5           chg_all_lead            7.633459        log1p_BEST_ASK
# 6            chg_all_lag            5.380802          chg_all_lead
# 7           log1p_ask_ex            3.503737          log1p_ask_ex
# 8         log1p_BEST_ASK            3.351737           chg_all_lag
# 9           log1p_bid_ex            2.677881  log1p_price_all_lead
# 10  log1p_price_all_lead            2.629573          log1p_bid_ex
# 11        log1p_BEST_BID            2.006848     log1p_trade_price
# 12     log1p_trade_price            1.516360        log1p_BEST_BID
# 13            chg_ex_lag            1.399953            chg_ex_lag
# 14           chg_ex_lead            1.253029   log1p_price_ex_lead
# 15   log1p_price_ex_lead            1.117642           chg_ex_lead
# 16   log1p_price_all_lag            0.605240   log1p_price_all_lag
# 17    log1p_price_ex_lag            0.351596    log1p_price_ex_lag
#
#     fold_1_Importances     fold_2_Feature Id  fold_2_Importances
# 0            19.913359            rel_ask_ex           19.104817
# 1            15.909112      bid_ask_ratio_ex           18.987904
# 2            15.302069            rel_bid_ex           16.257441
# 3             7.923958          BEST_rel_bid            7.960123
# 4             7.831309          BEST_rel_ask            7.812259
# 5             7.146806        log1p_BEST_ASK            7.660703
# 6             6.456127          log1p_ask_ex            5.102793
# 7             5.458561          chg_all_lead            4.689283
# 8             3.624757           chg_all_lag            2.565721
# 9             2.426429  log1p_price_all_lead            2.030976
# 10            1.853473     log1p_trade_price            1.705790
# 11            1.425544          log1p_bid_ex            1.648658
# 12            1.321100            chg_ex_lag            1.485121
# 13            1.239127        log1p_BEST_BID            1.239511
# 14            0.819183   log1p_price_ex_lead            0.508708
# 15            0.704378           chg_ex_lead            0.481008
# 16            0.332717    log1p_price_ex_lag            0.423941
# 17            0.311992   log1p_price_all_lag            0.335244

# %%
results_cv, results_oos, results_fi = evaluate(
    [*classical_features_no_transform, *size_features_no_transform], []
)
# Out:
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# {'fit_time': array([104.58673477, 103.29419017, 101.88424706]), 'score_time': array([3.14695215, 3.14843535, 3.09839463]), 'estimator': [<catboost.core.CatBoostClassifier object at 0x7f17b8a7e7f0>, <catboost.core.CatBoostClassifier object at 0x7f17c7873ee0>, <catboost.core.CatBoostClassifier object at 0x7f17af81d430>], 'test_score': array([0.86247646, 0.85755816, 0.83622475])}
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %%
results_cv
# Out:
#    test_score_cv
# 0       0.862476
# 1       0.857558
# 2       0.836225

# %%
results_oos
# Out:
#    fold  acc_train   acc_val  acc_test
# 0     0   0.857773  0.736869  0.711380
# 1     1   0.860659  0.734654  0.710238
# 2     2   0.861461  0.724263  0.696201

# %%
results_fi
# Out:
#         fold_0_Feature Id  fold_0_Importances      fold_1_Feature Id  \
# 0              rel_ask_ex           12.612576             rel_bid_ex
# 1             ask_size_ex           11.493982             rel_ask_ex
# 2             bid_size_ex           10.144316  bid_ask_size_ratio_ex
# 3              rel_bid_ex            9.949764            ask_size_ex
# 4   bid_ask_size_ratio_ex            9.533182            bid_size_ex
# 5            BEST_rel_bid            6.963347        rel_bid_size_ex
# 6         rel_bid_size_ex            6.812533       bid_ask_ratio_ex
# 7            BEST_rel_ask            6.245576           BEST_rel_ask
# 8              TRADE_SIZE            4.669964             TRADE_SIZE
# 9         rel_ask_size_ex            4.384364        rel_ask_size_ex
# 10       bid_ask_ratio_ex            3.099288           BEST_rel_bid
# 11           chg_all_lead            2.565829                 ask_ex
# 12            chg_all_lag            2.308640               BEST_ASK
# 13            TRADE_PRICE            1.456582           chg_all_lead
# 14               BEST_BID            1.398219            chg_all_lag
# 15               BEST_ASK            1.318385               BEST_BID
# 16            chg_ex_lead            1.144527            TRADE_PRICE
# 17                 ask_ex            1.091005            chg_ex_lead
# 18         price_all_lead            0.802608                 bid_ex
# 19             chg_ex_lag            0.641327         price_all_lead
# 20                 bid_ex            0.567738             chg_ex_lag
# 21          price_ex_lead            0.538610          price_ex_lead
# 22           price_ex_lag            0.134324          price_all_lag
# 23          price_all_lag            0.123312           price_ex_lag
#
#     fold_1_Importances      fold_2_Feature Id  fold_2_Importances
# 0            10.182475             rel_ask_ex           11.326076
# 1             9.384389            bid_size_ex           10.943411
# 2             9.135271            ask_size_ex           10.518842
# 3             8.671358  bid_ask_size_ratio_ex            9.905341
# 4             8.640208             rel_bid_ex            8.396384
# 5             8.229752        rel_bid_size_ex            7.526561
# 6             7.792101       bid_ask_ratio_ex            7.419689
# 7             6.609483             TRADE_SIZE            6.297405
# 8             5.480719           BEST_rel_ask            5.368463
# 9             5.457203           BEST_rel_bid            4.796347
# 10            5.283369        rel_ask_size_ex            4.320900
# 11            2.356229               BEST_ASK            2.980020
# 12            2.319393                 ask_ex            2.198615
# 13            2.249199           chg_all_lead            1.471552
# 14            1.834509            TRADE_PRICE            1.279407
# 15            1.420834               BEST_BID            1.183437
# 16            1.248052            chg_all_lag            1.142086
# 17            0.909494         price_all_lead            0.790988
# 18            0.813406             chg_ex_lag            0.781662
# 19            0.681543            chg_ex_lead            0.500777
# 20            0.593377                 bid_ex            0.463816
# 21            0.473121          price_ex_lead            0.228102
# 22            0.146185          price_all_lag            0.108539
# 23            0.088329           price_ex_lag            0.051579

# %%
results_cv, results_oos, results_fi = evaluate(
    [*classical_features_no_transform, *size_features_log001p], []
)
# Out:
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# {'fit_time': array([104.1224792 , 103.63906527, 101.74330044]), 'score_time': array([3.05360603, 3.16042089, 3.04070044]), 'estimator': [<catboost.core.CatBoostClassifier object at 0x7f17b8a7e4f0>, <catboost.core.CatBoostClassifier object at 0x7f17c786ffa0>, <catboost.core.CatBoostClassifier object at 0x7f191417dd30>], 'test_score': array([0.8623199 , 0.85761296, 0.83622373])}
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %%
results_cv
# Out:
#    test_score_cv
# 0       0.862320
# 1       0.857613
# 2       0.836224

# %%
results_oos
# Out:
#    fold  acc_train   acc_val  acc_test
# 0     0   0.857678  0.736742  0.711212
# 1     1   0.860714  0.734679  0.709971
# 2     2   0.861425  0.724213  0.695957

# %%
results_fi
# Out:
#         fold_0_Feature Id  fold_0_Importances      fold_1_Feature Id  \
# 0              rel_ask_ex           12.641688             rel_bid_ex
# 1     log001p_ask_size_ex           11.408432             rel_ask_ex
# 2     log001p_bid_size_ex           10.191568  bid_ask_size_ratio_ex
# 3              rel_bid_ex            9.973127    log001p_ask_size_ex
# 4   bid_ask_size_ratio_ex            9.544057    log001p_bid_size_ex
# 5            BEST_rel_bid            6.874092        rel_bid_size_ex
# 6         rel_bid_size_ex            6.764436       bid_ask_ratio_ex
# 7            BEST_rel_ask            6.312749           BEST_rel_ask
# 8      log001p_TRADE_SIZE            4.704662           BEST_rel_bid
# 9         rel_ask_size_ex            4.394143     log001p_TRADE_SIZE
# 10       bid_ask_ratio_ex            3.078264        rel_ask_size_ex
# 11           chg_all_lead            2.588649               BEST_ASK
# 12            chg_all_lag            2.296174                 ask_ex
# 13            TRADE_PRICE            1.469941           chg_all_lead
# 14               BEST_BID            1.397582            chg_all_lag
# 15               BEST_ASK            1.296546               BEST_BID
# 16            chg_ex_lead            1.165659            TRADE_PRICE
# 17                 ask_ex            1.119847                 bid_ex
# 18         price_all_lead            0.812921            chg_ex_lead
# 19             chg_ex_lag            0.651534         price_all_lead
# 20          price_ex_lead            0.541159             chg_ex_lag
# 21                 bid_ex            0.492063          price_ex_lead
# 22          price_all_lag            0.142442          price_all_lag
# 23           price_ex_lag            0.138267           price_ex_lag
#
#     fold_1_Importances      fold_2_Feature Id  fold_2_Importances
# 0             9.902355             rel_ask_ex           11.243654
# 1             9.740444    log001p_bid_size_ex           10.971849
# 2             9.133761    log001p_ask_size_ex           10.501408
# 3             8.815559  bid_ask_size_ratio_ex            9.890220
# 4             8.779536             rel_bid_ex            8.509962
# 5             7.997798        rel_bid_size_ex            7.508173
# 6             7.746922       bid_ask_ratio_ex            7.396100
# 7             6.224303     log001p_TRADE_SIZE            6.335550
# 8             5.587097           BEST_rel_ask            5.386723
# 9             5.504333           BEST_rel_bid            4.762067
# 10            5.407847        rel_ask_size_ex            4.317600
# 11            2.318163               BEST_ASK            2.988778
# 12            2.276287                 ask_ex            2.146283
# 13            2.262058           chg_all_lead            1.478756
# 14            1.826343            TRADE_PRICE            1.293185
# 15            1.469269            chg_all_lag            1.172955
# 16            1.249787               BEST_BID            1.164046
# 17            0.910822         price_all_lead            0.798369
# 18            0.897227             chg_ex_lag            0.775481
# 19            0.656941            chg_ex_lead            0.483612
# 20            0.584282                 bid_ex            0.469691
# 21            0.481756          price_ex_lead            0.217647
# 22            0.143196          price_all_lag            0.131367
# 23            0.083916           price_ex_lag            0.056523

# %%
results_cv, results_oos, results_fi = evaluate(
    [*classical_features_no_transform, *size_features_log1p], []
)
# Out:
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# {'fit_time': array([104.16563058, 103.52602983, 101.98182058]), 'score_time': array([3.04467106, 2.9350853 , 3.07836866]), 'estimator': [<catboost.core.CatBoostClassifier object at 0x7f17c7873100>, <catboost.core.CatBoostClassifier object at 0x7f17c786ffd0>, <catboost.core.CatBoostClassifier object at 0x7f191417d4f0>], 'test_score': array([0.86242593, 0.8575175 , 0.8361852 ])}
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# /usr/local/lib/python3.8/dist-packages/catboost/core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,

# %%
results_cv
# Out:
#    test_score_cv
# 0       0.862426
# 1       0.857518
# 2       0.836185

# %%
results_oos
# Out:
#    fold  acc_train   acc_val  acc_test
# 0     0   0.857722  0.736836  0.711281
# 1     1   0.860661  0.734597  0.710053
# 2     2   0.861418  0.724236  0.696194

# %%
results_fi
# Out:
#         fold_0_Feature Id  fold_0_Importances      fold_1_Feature Id  \
# 0              rel_ask_ex           12.688185             rel_bid_ex
# 1       log1p_ask_size_ex           11.577071             rel_ask_ex
# 2              rel_bid_ex           10.145543  bid_ask_size_ratio_ex
# 3       log1p_bid_size_ex           10.110876      log1p_ask_size_ex
# 4   bid_ask_size_ratio_ex            9.518410      log1p_bid_size_ex
# 5            BEST_rel_bid            6.914585        rel_bid_size_ex
# 6         rel_bid_size_ex            6.842888       bid_ask_ratio_ex
# 7            BEST_rel_ask            6.140031           BEST_rel_ask
# 8        log1p_TRADE_SIZE            4.539013           BEST_rel_bid
# 9         rel_ask_size_ex            4.399959       log1p_TRADE_SIZE
# 10       bid_ask_ratio_ex            3.047864        rel_ask_size_ex
# 11           chg_all_lead            2.557754               BEST_ASK
# 12            chg_all_lag            2.291119           chg_all_lead
# 13            TRADE_PRICE            1.456369                 ask_ex
# 14               BEST_ASK            1.418679            chg_all_lag
# 15               BEST_BID            1.413072               BEST_BID
# 16            chg_ex_lead            1.167858            TRADE_PRICE
# 17                 ask_ex            0.982852                 bid_ex
# 18         price_all_lead            0.813474            chg_ex_lead
# 19             chg_ex_lag            0.644205         price_all_lead
# 20          price_ex_lead            0.543471             chg_ex_lag
# 21                 bid_ex            0.535729          price_ex_lead
# 22           price_ex_lag            0.131565          price_all_lag
# 23          price_all_lag            0.119427           price_ex_lag
#
#     fold_1_Importances      fold_2_Feature Id  fold_2_Importances
# 0            10.082419             rel_ask_ex           11.344160
# 1             9.590845      log1p_bid_size_ex           10.966773
# 2             9.150461      log1p_ask_size_ex           10.532778
# 3             8.791152  bid_ask_size_ratio_ex            9.914168
# 4             8.758232             rel_bid_ex            8.399537
# 5             7.977102        rel_bid_size_ex            7.504351
# 6             7.748280       bid_ask_ratio_ex            7.386279
# 7             6.253999       log1p_TRADE_SIZE            6.301617
# 8             5.620359           BEST_rel_ask            5.360860
# 9             5.494301           BEST_rel_bid            4.827735
# 10            5.348097        rel_ask_size_ex            4.320807
# 11            2.459962               BEST_ASK            2.990931
# 12            2.265785                 ask_ex            2.194037
# 13            2.232977           chg_all_lead            1.454365
# 14            1.835289            TRADE_PRICE            1.314482
# 15            1.372199               BEST_BID            1.157731
# 16            1.196050            chg_all_lag            1.154880
# 17            0.952209             chg_ex_lag            0.775494
# 18            0.898965         price_all_lead            0.763934
# 19            0.646418            chg_ex_lead            0.500403
# 20            0.606985                 bid_ex            0.433304
# 21            0.482324          price_ex_lead            0.232351
# 22            0.153971          price_all_lag            0.114271
# 23            0.081618           price_ex_lag            0.054754
