# %% [markdown]
# <a href="https://colab.research.google.com/github/KarelZe/thesis/blob/baseline/notebooks/3.0-mb-classical_rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gcsfs==2022.10.0
# !pip install numpy==1.23.4
# !pip install pandas==1.5.1
# !pip install fastparquet
# !pip install scikit-learn==1.1.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gcsfs==2022.10.0 in /usr/local/lib/python3.7/dist-packages (2022.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (3.8.3)
# Requirement already satisfied: fsspec==2022.10.0 in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (2022.10.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (0.4.6)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (4.4.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (2.5.0)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (2.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gcsfs==2022.10.0) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (4.1.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (2.1.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (0.13.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (6.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs==2022.10.0) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs==2022.10.0) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs==2022.10.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.2->gcsfs==2022.10.0) (5.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs==2022.10.0) (0.4.8)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2022.10.0) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib->gcsfs==2022.10.0) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==2022.10.0) (3.2.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs==2022.10.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs==2022.10.0) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gcsfs==2022.10.0) (1.24.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs==2022.10.0) (2.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs==2022.10.0) (2.8.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage->gcsfs==2022.10.0) (2.3.2)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs==2022.10.0) (3.19.6)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.7/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->gcsfs==2022.10.0) (1.56.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.7/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage->gcsfs==2022.10.0) (1.5.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement numpy==1.23.4 (from versions: 1.3.0, 1.4.1, 1.5.0, 1.5.1, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.7.1, 1.7.2, 1.8.0, 1.8.1, 1.8.2, 1.9.0, 1.9.1, 1.9.2, 1.9.3, 1.10.0.post2, 1.10.1, 1.10.2, 1.10.4, 1.11.0, 1.11.1, 1.11.2, 1.11.3, 1.12.0, 1.12.1, 1.13.0rc1, 1.13.0rc2, 1.13.0, 1.13.1, 1.13.3, 1.14.0rc1, 1.14.0, 1.14.1, 1.14.2, 1.14.3, 1.14.4, 1.14.5, 1.14.6, 1.15.0rc1, 1.15.0rc2, 1.15.0, 1.15.1, 1.15.2, 1.15.3, 1.15.4, 1.16.0rc1, 1.16.0rc2, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.16.4, 1.16.5, 1.16.6, 1.17.0rc1, 1.17.0rc2, 1.17.0, 1.17.1, 1.17.2, 1.17.3, 1.17.4, 1.17.5, 1.18.0rc1, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 1.18.5, 1.19.0rc1, 1.19.0rc2, 1.19.0, 1.19.1, 1.19.2, 1.19.3, 1.19.4, 1.19.5, 1.20.0rc1, 1.20.0rc2, 1.20.0, 1.20.1, 1.20.2, 1.20.3, 1.21.0rc1, 1.21.0rc2, 1.21.0, 1.21.1, 1.21.2, 1.21.3, 1.21.4, 1.21.5, 1.21.6)
# ERROR: No matching distribution found for numpy==1.23.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement pandas==1.5.1 (from versions: 0.1, 0.2, 0.3.0, 0.4.0, 0.4.1, 0.4.2, 0.4.3, 0.5.0, 0.6.0, 0.6.1, 0.7.0, 0.7.1, 0.7.2, 0.7.3, 0.8.0, 0.8.1, 0.9.0, 0.9.1, 0.10.0, 0.10.1, 0.11.0, 0.12.0, 0.13.0, 0.13.1, 0.14.0, 0.14.1, 0.15.0, 0.15.1, 0.15.2, 0.16.0, 0.16.1, 0.16.2, 0.17.0, 0.17.1, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.19.2, 0.20.0, 0.20.1, 0.20.2, 0.20.3, 0.21.0, 0.21.1, 0.22.0, 0.23.0, 0.23.1, 0.23.2, 0.23.3, 0.23.4, 0.24.0, 0.24.1, 0.24.2, 0.25.0, 0.25.1, 0.25.2, 0.25.3, 1.0.0, 1.0.1, 1.0.2, 1.0.3, 1.0.4, 1.0.5, 1.1.0, 1.1.1, 1.1.2, 1.1.3, 1.1.4, 1.1.5, 1.2.0, 1.2.1, 1.2.2, 1.2.3, 1.2.4, 1.2.5, 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.3.4, 1.3.5)
# ERROR: No matching distribution found for pandas==1.5.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.21.6)
# Requirement already satisfied: cramjam>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2.6.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2022.10.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement scikit-learn==1.1.3 (from versions: 0.9, 0.10, 0.11, 0.12, 0.12.1, 0.13, 0.13.1, 0.14, 0.14.1, 0.15.0b1, 0.15.0b2, 0.15.0, 0.15.1, 0.15.2, 0.16b1, 0.16.0, 0.16.1, 0.17b1, 0.17, 0.17.1, 0.18, 0.18.1, 0.18.2, 0.19b2, 0.19.0, 0.19.1, 0.19.2, 0.20rc1, 0.20.0, 0.20.1, 0.20.2, 0.20.3, 0.20.4, 0.21rc2, 0.21.0, 0.21.1, 0.21.2, 0.21.3, 0.22rc2.post1, 0.22rc3, 0.22, 0.22.1, 0.22.2, 0.22.2.post1, 0.23.0rc1, 0.23.0, 0.23.1, 0.23.2, 0.24.dev0, 0.24.0rc1, 0.24.0, 0.24.1, 0.24.2, 1.0rc1, 1.0rc2, 1.0, 1.0.1, 1.0.2)
# ERROR: No matching distribution found for scikit-learn==1.1.3

# %%
import os
import random

import gcsfs
import google.auth
from google.colab import auth


import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
auth.authenticate_user()
credentials, _ = google.auth.default()
fs = gcsfs.GCSFileSystem(project="thesis", token=credentials)
fs_prefix = "gs://"

# %%
# set fixed seed
def seed_everything(seed):
    """
    Seeds basic parameters for reproducibility of results
    """
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)


seed = 42
seed_everything(seed)

# %%
# test = pd.read_parquet(
#     f"gs://thesis-bucket-option-trade-classification/data/preprocessed/matched_ise_quotes_2017.parquet",
#     engine="fastparquet",
# )

columns = ['buy_sell',"EXPIRATION", "QUOTE_DATETIME", "TRADE_PRICE", 
           "price_ex_lag", "price_all_lag","price_ex_lead", "price_all_lead", 
           "TRADE_SIZE","ask_size_ex","bid_size_ex"]

train = pd.read_parquet(
    f"gs://thesis-bucket-option-trade-classification/data/preprocessed/train_set_60.parquet",
    engine="fastparquet",columns=columns
)
val = pd.read_parquet(
    f"gs://thesis-bucket-option-trade-classification/data/preprocessed/val_set_20.parquet",
    engine="fastparquet",columns=columns
)
test = pd.read_parquet(
    f"gs://thesis-bucket-option-trade-classification/data/preprocessed/test_set_20.parquet",
    engine="fastparquet",columns=columns
)

X_print = pd.concat([train, val, test])

# %% [markdown]
# ### Robustness

# %%
# Copy unscaled columns
#X_print = test.copy()
# X_print = pd.concat([train, val, test])

# add baseline results
X_print["rule"] = "Baseline"
X_print["buy_sell_predicted"] = 0

# # prepare columns for printing
# X_print["ttm"] = (
#     X_print["EXPIRATION"].dt.to_period("M")
#     - X_print["QUOTE_DATETIME"].dt.to_period("M")
# ).apply(lambda x: x.n)
X_print["year"] = X_print["QUOTE_DATETIME"].dt.year

bins_tradesize = [0, 1, 3, 5, 11, np.inf]
trade_size_labels = ["(0,1]", "(1,3]", "(3,5]", "(5,11]", ">11"]
X_print["TRADE_SIZE_binned"] = pd.cut(
    X_print["TRADE_SIZE"], bins_tradesize, labels=trade_size_labels
)

bins_years = [2004, 2007, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]
year_labels = [
    "2005-2007",
    "2008-2010",
    "2011",
    "2012",
    "2013",
    "2014",
    "2015",
    "2016",
    "2017",
]
X_print["year_binned"] = pd.cut(X_print["year"], bins_years, labels=year_labels)

bins_ttm = [0, 1, 2, 3, 6, 12, np.inf]
ttm_labels = [
    "ttm <= 1 month",
    "ttm (1-2] month",
    "ttm (2-3] month",
    "ttm (3-6] month",
    "ttm (6-12] month",
    "ttm > 12 month",
]
#X_print["ttm_binned"] = pd.cut(X_print["ttm"], bins_ttm, labels=ttm_labels)

# TODO: Security type
# TODO: Moneyness
# TODO: time from previous trade; same underlying or any?

# %%
def check_robustness(criterion: str = "year_binned") -> pd.DataFrame:
    """
    Check robustness of rules by calculating the accuracy for a given
    criterion and rules.

    Example:
    rule		Baseline
    TRADE_SIZE_binned
    (0,1]	  0.710966
    (1,3]	  0.717664
    (3,5]	  0.715195
    (5,11]	0.699428
    >11	  	0.688348

    Args:
        criterion (str, optional): criterion to check robustness for.
        Defaults to "year_binned".

    Returns:
        pd.DataFrame: DataFrame with accuracy of rules. Rule in columns and
        criterion values in rows.
    """

    # fill others with
    # X_print["buy_sell_predicted"] = X_print["buy_sell_predicted"].map(
    #     lambda l: l if not np.isnan(l) else 0
    # )

    # # fill others randomly
    X_print["buy_sell_predicted"] = X_print["buy_sell_predicted"].map(
        lambda l: l if not np.isnan(l) else np.random.choice([-1, 1])
    )
    # filter = X_print["buy_sell_predicted"].notna()

    # cuculate average over columns if multiple subsets are combined
    results = (
        X_print.groupby(["rule", criterion])[["buy_sell", "buy_sell_predicted"]]
        .apply(lambda x: accuracy_score(x["buy_sell"], x["buy_sell_predicted"]))
        .unstack(level=0)
        #.assign(avg=lambda x: x.mean(axis=1))
        .mul(100)
    )
    return results

# %%
def combine_results(revised:pd.DataFrame, base:pd.DataFrame)->pd.DataFrame:
  """
  Generate print layout like in Grauer et al.

  Example:
  TRADE_SIZE_binned	(0,1]	(1,3]	(3,5]	(5,11]	>11
  rule					
  tick rule (all)	62.29 (10.38)	62.91 (10.27)	63.54 (11.08)	58.64 (5.62)	55.41 (-0.94)
  """
  combo = base.copy()
  for i, col in enumerate(combo.columns):
    col_other = revised.columns[i]
    combo[col] = revised[col_other].round(2).astype(str) + ' (' + (revised[col_other] - base[col]).round(2).astype(str) + ')'
  return combo.T

# %% [markdown]
# ## Classical rules

# %%
# tick rule
# FIXME: Discuss with Grauer et al what is used in table 9 ISE at '=='? How is their accuracy defined?

subset = "all"

# print(X_print[f"price_{subset}_lag"].isna().sum())
# X_print[f"price_{subset}_lag"].fillna(0, inplace=True)
# filter = X_print[f"price_{subset}_lag"].isna()
# print(filter.sum())

# FIXME: adjustment to classical algorithm if no price_all_lag is found.
tt = np.where(X_print["TRADE_PRICE"] > X_print[f"price_{subset}_lag"], 1,
              np.where(X_print["TRADE_PRICE"] < X_print[f"price_{subset}_lag"],-1, 
                       np.nan))

X_print["buy_sell_predicted"] = tt
# X_print["buy_sell_predicted"][filter] = np.nan

X_print["rule"] = f"tick test ({subset})"

# 2017	0.535319	0.535319
# soll 53,22 (table 3) 54,46 (table 9)

# 2005-2007	0.508497	0.508497
# 2008-2010	0.520588	0.520588
# 2011	0.547742	0.547742
# 2012	0.558078	0.558078
# 2013	0.552743	0.552743
# 2014	0.552471	0.552471
# 2015	0.538636	0.538636
# 2016	0.535457	0.535457
# 2017	0.538028	0.538028

# %%
N_obs = len(X_print)
N_classifiable = X_print["buy_sell_predicted"].notna().sum()
N_correct = (X_print["buy_sell"] == X_print["buy_sell_predicted"]).sum()

not_classified_perc = (N_obs - N_classifiable)/N_obs * 100.0
# not_classified_perc = 0
success_ind = (N_correct / N_classifiable) * 100.0
success_total = (50 * not_classified_perc + success_ind * (100 - not_classified_perc)) / 100.0

print(success_total)
# Out:
# 53.31403317718873

# %%
X_print[X_print["buy_sell_predicted"].isna()].head(50)
# Out:
#       buy_sell EXPIRATION      QUOTE_DATETIME  TRADE_PRICE  price_ex_lag  \
# 489          1 2005-09-17 2005-05-02 09:33:00     2.700000           NaN
# 558         -1 2005-06-18 2005-05-02 09:33:51     0.050000           NaN
# 572         -1 2005-06-18 2005-05-02 09:34:08     0.050000           NaN
# 693          1 2005-06-18 2005-05-02 09:35:35     0.450000           NaN
# 717          1 2005-05-21 2005-05-02 09:35:51     0.050000           NaN
# 728          1 2005-12-17 2005-05-02 09:36:06     4.300000           NaN
# 1161         1 2005-10-22 2005-05-02 09:47:04     0.150000           NaN
# 1283        -1 2005-12-17 2005-05-02 09:49:48     1.450000           NaN
# 1316        -1 2005-06-18 2005-05-02 09:50:50     5.600000           NaN
# 1373        -1 2005-06-18 2005-05-02 09:52:39     2.900000           NaN
# 1454        -1 2006-01-21 2005-05-02 09:55:49     6.400000           NaN
# 1466        -1 2005-06-18 2005-05-02 09:56:28     0.200000           NaN
# 1781         1 2005-10-22 2005-05-02 10:05:51     4.900000           NaN
# 1813         1 2005-05-21 2005-05-02 10:06:36     0.050000           NaN
# 2082        -1 2005-12-17 2005-05-02 10:14:30    14.200000           NaN
# 2106         1 2007-01-20 2005-05-02 10:14:47     2.100000           NaN
# 2132        -1 2005-12-17 2005-05-02 10:15:46     5.800000           NaN
# 2140        -1 2005-12-17 2005-05-02 10:16:08     5.800000           NaN
# 2218        -1 2005-12-17 2005-05-02 10:19:13     7.700000           NaN
# 2254         1 2005-11-19 2005-05-02 10:20:43    11.200000           NaN
# 2414         1 2005-07-16 2005-05-02 10:26:30     1.200000           NaN
# 2435         1 2005-06-18 2005-05-02 10:27:22     0.350000           NaN
# 2693         1 2005-08-20 2005-05-02 10:37:41     9.900000           NaN
# 2821        -1 2005-09-17 2005-05-02 10:43:27     4.000000           NaN
# 2825        -1 2005-09-17 2005-05-02 10:43:33     4.000000           NaN
# 2968        -1 2005-06-18 2005-05-02 10:51:15     0.500000           NaN
# 3120         1 2005-06-18 2005-05-02 10:58:55     0.100000           NaN
# 3428        -1 2005-06-18 2005-05-02 11:17:54     0.200000           NaN
# 3433        -1 2005-11-19 2005-05-02 11:18:02    19.200001           NaN
# 3506        -1 2005-12-17 2005-05-02 11:21:08    10.200000           NaN
# 3783        -1 2005-09-17 2005-05-02 11:38:35     4.000000           NaN
# 3865         1 2005-12-17 2005-05-02 11:42:29    13.200000           NaN
# 4137        -1 2005-09-17 2005-05-02 11:58:27     4.000000           NaN
# 4356        -1 2005-12-17 2005-05-02 12:12:01     5.500000           NaN
# 4758        -1 2005-06-18 2005-05-02 12:38:32     5.600000           NaN
# 4840         1 2005-06-18 2005-05-02 12:44:54     0.100000           NaN
# 4899        -1 2007-01-20 2005-05-02 12:48:21     0.600000           NaN
# 4903        -1 2005-06-18 2005-05-02 12:49:00     0.600000           NaN
# 4960        -1 2005-11-19 2005-05-02 12:54:38     6.600000           NaN
# 4990        -1 2005-12-17 2005-05-02 12:56:19     0.300000           NaN
# 5658        -1 2005-12-17 2005-05-02 13:43:06     3.100000           NaN
# 6013         1 2005-06-18 2005-05-02 14:04:36     1.800000           NaN
# 6235         1 2007-01-20 2005-05-02 14:18:46    15.900000           NaN
# 6259        -1 2005-05-21 2005-05-02 14:21:19     9.010000           NaN
# 6438        -1 2007-01-20 2005-05-02 14:37:06     3.400000           NaN
# 6451        -1 2005-12-17 2005-05-02 14:38:04     2.450000           NaN
# 6565        -1 2005-12-17 2005-05-02 14:47:23     0.750000           NaN
# 7269         1 2005-06-18 2005-05-02 15:32:10     0.050000           NaN
# 7373         1 2005-05-21 2005-05-02 15:38:33     0.050000           NaN
# 7447        -1 2005-10-22 2005-05-02 15:42:09     1.850000           NaN
#
#       price_all_lag  price_ex_lead  price_all_lead  TRADE_SIZE  ask_size_ex  \
# 489             NaN           1.85            1.85           4         11.0
# 558             NaN            NaN             NaN          10        587.0
# 572             NaN            NaN             NaN          76       1140.0
# 693             NaN           0.30            0.30           5          NaN
# 717             NaN            NaN             NaN           5         70.0
# 728             NaN           3.10            3.20          20         50.0
# 1161            NaN           0.05            0.10           2        595.0
# 1283            NaN           1.60            1.60           2         50.0
# 1316            NaN            NaN            8.90           5        569.0
# 1373            NaN           2.45            2.45          10        259.0
# 1454            NaN           7.60            7.60          10        129.0
# 1466            NaN            NaN            0.25          75        174.0
# 1781            NaN           5.00            5.00          30        165.0
# 1813            NaN            NaN             NaN           5       7098.0
# 2082            NaN          12.80           13.20          10         16.0
# 2106            NaN           1.90            2.15          10         10.0
# 2132            NaN           5.70            5.70           1        157.0
# 2140            NaN           5.70            5.70           1        174.0
# 2218            NaN           5.10            6.60          10       1011.0
# 2254            NaN           3.50            3.50           3        750.0
# 2414            NaN           1.25            1.25           2        284.0
# 2435            NaN           0.10            0.10          10        285.0
# 2693            NaN          11.60           11.60          10        143.0
# 2821            NaN           3.90            3.90          25         26.0
# 2825            NaN           3.90            3.90           1          1.0
# 2968            NaN           0.55            0.55           6          5.0
# 3120            NaN            NaN             NaN           4        464.0
# 3428            NaN           0.40            0.15           5        167.0
# 3433            NaN          17.90           20.10           6         30.0
# 3506            NaN           8.50           12.00           5         12.0
# 3783            NaN           3.90            3.90          25        248.0
# 3865            NaN          19.40           13.40           2         20.0
# 4137            NaN           3.90            3.90          10        122.0
# 4356            NaN           3.00            4.30          10        211.0
# 4758            NaN           3.00            3.00          10         41.0
# 4840            NaN            NaN             NaN           6        620.0
# 4899            NaN           0.65            0.65           5        529.0
# 4903            NaN           0.35            0.55          10         20.0
# 4960            NaN           6.90            6.90           5        103.0
# 4990            NaN           0.40            0.35          60         60.0
# 5658            NaN           1.25            2.55          20        925.0
# 6013            NaN           1.10            1.35           4         38.0
# 6235            NaN          15.50           16.40           2         49.0
# 6259            NaN            NaN             NaN          10        143.0
# 6438            NaN           2.30            3.30          10         30.0
# 6451            NaN           2.60            2.60          20         25.0
# 6565            NaN           0.50            0.40          15         25.0
# 7269            NaN            NaN             NaN          60        228.0
# 7373            NaN            NaN             NaN           1        139.0
# 7447            NaN           1.80            1.80           6         39.0
#
#       bid_size_ex             rule  buy_sell_predicted  year  \
# 489           4.0  tick test (all)                 NaN  2005
# 558           0.0  tick test (all)                 NaN  2005
# 572           0.0  tick test (all)                 NaN  2005
# 693           NaN  tick test (all)                 NaN  2005
# 717           0.0  tick test (all)                 NaN  2005
# 728          50.0  tick test (all)                 NaN  2005
# 1161        367.0  tick test (all)                 NaN  2005
# 1283         50.0  tick test (all)                 NaN  2005
# 1316        258.0  tick test (all)                 NaN  2005
# 1373        218.0  tick test (all)                 NaN  2005
# 1454         40.0  tick test (all)                 NaN  2005
# 1466        123.0  tick test (all)                 NaN  2005
# 1781         30.0  tick test (all)                 NaN  2005
# 1813          0.0  tick test (all)                 NaN  2005
# 2082         94.0  tick test (all)                 NaN  2005
# 2106         93.0  tick test (all)                 NaN  2005
# 2132        155.0  tick test (all)                 NaN  2005
# 2140        251.0  tick test (all)                 NaN  2005
# 2218       1207.0  tick test (all)                 NaN  2005
# 2254        150.0  tick test (all)                 NaN  2005
# 2414          2.0  tick test (all)                 NaN  2005
# 2435        532.0  tick test (all)                 NaN  2005
# 2693         57.0  tick test (all)                 NaN  2005
# 2821        180.0  tick test (all)                 NaN  2005
# 2825        180.0  tick test (all)                 NaN  2005
# 2968         29.0  tick test (all)                 NaN  2005
# 3120         68.0  tick test (all)                 NaN  2005
# 3428       2136.0  tick test (all)                 NaN  2005
# 3433         98.0  tick test (all)                 NaN  2005
# 3506         60.0  tick test (all)                 NaN  2005
# 3783         91.0  tick test (all)                 NaN  2005
# 3865         20.0  tick test (all)                 NaN  2005
# 4137         77.0  tick test (all)                 NaN  2005
# 4356        457.0  tick test (all)                 NaN  2005
# 4758         93.0  tick test (all)                 NaN  2005
# 4840        394.0  tick test (all)                 NaN  2005
# 4899        297.0  tick test (all)                 NaN  2005
# 4903         46.0  tick test (all)                 NaN  2005
# 4960        128.0  tick test (all)                 NaN  2005
# 4990       1263.0  tick test (all)                 NaN  2005
# 5658        638.0  tick test (all)                 NaN  2005
# 6013         55.0  tick test (all)                 NaN  2005
# 6235          2.0  tick test (all)                 NaN  2005
# 6259        153.0  tick test (all)                 NaN  2005
# 6438         10.0  tick test (all)                 NaN  2005
# 6451         35.0  tick test (all)                 NaN  2005
# 6565         45.0  tick test (all)                 NaN  2005
# 7269        440.0  tick test (all)                 NaN  2005
# 7373          0.0  tick test (all)                 NaN  2005
# 7447        191.0  tick test (all)                 NaN  2005
#
#      TRADE_SIZE_binned year_binned
# 489              (3,5]         NaN
# 558             (5,11]         NaN
# 572                >11         NaN
# 693              (3,5]         NaN
# 717              (3,5]         NaN
# 728                >11         NaN
# 1161             (1,3]         NaN
# 1283             (1,3]         NaN
# 1316             (3,5]         NaN
# 1373            (5,11]         NaN
# 1454            (5,11]         NaN
# 1466               >11         NaN
# 1781               >11         NaN
# 1813             (3,5]         NaN
# 2082            (5,11]         NaN
# 2106            (5,11]         NaN
# 2132             (0,1]         NaN
# 2140             (0,1]         NaN
# 2218            (5,11]         NaN
# 2254             (1,3]         NaN
# 2414             (1,3]         NaN
# 2435            (5,11]         NaN
# 2693            (5,11]         NaN
# 2821               >11         NaN
# 2825             (0,1]         NaN
# 2968            (5,11]         NaN
# 3120             (3,5]         NaN
# 3428             (3,5]         NaN
# 3433            (5,11]         NaN
# 3506             (3,5]         NaN
# 3783               >11         NaN
# 3865             (1,3]         NaN
# 4137            (5,11]         NaN
# 4356            (5,11]         NaN
# 4758            (5,11]         NaN
# 4840            (5,11]         NaN
# 4899             (3,5]         NaN
# 4903            (5,11]         NaN
# 4960             (3,5]         NaN
# 4990               >11         NaN
# 5658               >11         NaN
# 6013             (3,5]         NaN
# 6235             (1,3]         NaN
# 6259            (5,11]         NaN
# 6438            (5,11]         NaN
# 6451               >11         NaN
# 6565               >11         NaN
# 7269               >11         NaN
# 7373             (0,1]         NaN
# 7447            (5,11]         NaN

# %%
accuracy_score(X_print["buy_sell"], X_print["buy_sell_predicted"])
# Out:
# 0.5321308761302265

# %%
check_robustness("year_binned")
# Out:
# rule         tick test (all)
# year_binned
# 2005-2007          50.906782
# 2008-2010          51.977173
# 2011               54.622561
# 2012               55.540790
# 2013               55.073888
# 2014               54.991957
# 2015               53.515099
# 2016               53.020268
# 2017               53.531859

# %%
ts_tick = check_robustness("TRADE_SIZE_binned")
ts_tick
# Out:
# rule               tick test (all)
# TRADE_SIZE_binned
# (0,1]                    51.914686
# (1,3]                    52.638455
# (3,5]                    52.458272
# (5,11]                   53.021104
# >11                      56.345046

# %%
# trade size rule

subset = "ex"

bid_eq_ask = X_print[f"ask_size_{subset}"] == X_print[f"bid_size_{subset}"]

# "matches either"
ts_eq_bid = (X_print["TRADE_SIZE"] == X_print[f"bid_size_{subset}"]) & -bid_eq_ask
ts_eq_ask = (X_print["TRADE_SIZE"] == X_print[f"ask_size_{subset}"]) & -bid_eq_ask

# trade size + tick rule
X_print["buy_sell_predicted"] = np.where(ts_eq_bid, 1.0, np.where(ts_eq_ask, -1.0, tt))


X_print["rule"] = "trade size + tick test"

# %%
accuracy_score(X_print["buy_sell"], X_print["buy_sell_predicted"])
# Out:
# 0.6052803661477245

# %%
check_robustness("year_binned")
# Out:
# rule         trade size + tick test
# year_binned
# 2005-2007                 65.047677
# 2008-2010                 61.389279
# 2011                      58.762266
# 2012                      58.645439
# 2013                      59.729238
# 2014                      62.203745
# 2015                      58.523800
# 2016                      58.223800
# 2017                      59.093800

# %%
ts_ts_tick = check_robustness("TRADE_SIZE_binned")

# %%
combine_results(ts_ts_tick, ts_tick)
# Out:
# TRADE_SIZE_binned          (0,1]          (1,3]          (3,5]        (5,11]  \
# rule
# tick test (all)    62.29 (10.38)  62.91 (10.28)  63.54 (11.08)  58.64 (5.61)
#
# TRADE_SIZE_binned            >11
# rule
# tick test (all)    55.41 (-0.93)

# %%
# FIXME: look at edge case where price_all_lag is null / not there

isna_sum_ts_binned = X_print.groupby(["TRADE_SIZE_binned"]).agg({'price_all_lag': lambda x: x.isnull().sum()})
isna_sum_ts_binned
# Out:
#                    price_all_lag
# TRADE_SIZE_binned
# (0,1]                     300619
# (1,3]                     206402
# (3,5]                     141241
# (5,11]                    220487
# >11                       187005

# %% [markdown]
# ## Reverse tick test

# %%
# reverse tick rule
subset = "all"

rev_tt = np.where(
     X_print[f"price_{subset}_lead"] < X_print["TRADE_PRICE"],
    1,
    np.where(X_print[f"price_{subset}_lead"] > X_print["TRADE_PRICE"], -1, np.NaN),
)

X_print["buy_sell_predicted"] = rev_tt 
filter = X_print[f"price_{subset}_lead"].isna()
print(filter.sum())

X_print["rule"] = "reverse tick rule"
# Out:
# 1622715

# %%
check_robustness("year_binned")
# Out:
# rule         reverse tick rule
# year_binned
# 2005-2007            56.548399
# 2008-2010            55.839899
# 2011                 55.811060
# 2012                 55.886015
# 2013                 55.118399
# 2014                 55.053000
# 2015                 53.533763
# 2016                 53.862434
# 2017                 54.649611

# %%
ts_rev_tick = check_robustness("TRADE_SIZE_binned")
ts_rev_tick
# Out:
# rule               reverse tick rule
# TRADE_SIZE_binned
# (0,1]                      55.275953
# (1,3]                      55.659477
# (3,5]                      56.106639
# (5,11]                     54.882484
# >11                        54.557590

# %%
# trade size + rev tick rule

X_print["buy_sell_predicted"] = np.where(ts_eq_bid, 1.0, np.where(ts_eq_ask, -1.0, rev_tt))
X_print["rule"] = "trade size + tick test"

# %%
ts_ts_rev_tick = check_robustness("TRADE_SIZE_binned")
ts_ts_rev_tick
# Out:
# rule               trade size + tick test
# TRADE_SIZE_binned
# (0,1]                           63.126941
# (1,3]                           63.528690
# (3,5]                           64.523715
# (5,11]                          59.128081
# >11                             54.606471

# %%
combine_results(ts_ts_rev_tick, ts_rev_tick)
# Out:
# TRADE_SIZE_binned         (0,1]         (1,3]         (3,5]        (5,11]  \
# rule
# reverse tick rule  63.13 (7.85)  63.53 (7.87)  64.52 (8.42)  59.13 (4.25)
#
# TRADE_SIZE_binned           >11
# rule
# reverse tick rule  54.61 (0.05)

# %%
isna_sum_ts_binned = X_print.groupby(["TRADE_SIZE_binned"]).agg({'price_all_lead': lambda x: x.isnull().sum()})
isna_sum_ts_binned
# Out:
#                    price_all_lead
# TRADE_SIZE_binned
# (0,1]                      431123
# (1,3]                      307379
# (3,5]                      221001
# (5,11]                     352634
# >11                        310578

# %% [markdown]
# ## Quote rule

# %%
# quote rule
# TODO: Variants QR (NBBO), QUOTE_RULE (ISE) etc.
subset = 'ex'

mid = 0.5 * (X_print[f"ask_{subset}"] + X_print[f"bid_{subset}"])
qr = np.where(
    X_print["TRADE_PRICE"] > mid, 1, np.where(X_print["TRADE_PRICE"] < mid, -1, np.nan)
)
X_print["buy_sell_predicted"] = qr

X_print["rule"] = "quote rule"

# %%
# check_robustness("year_binned")

# %%
# X_print["buy_sell_predicted"] = np.where(ts_eq_bid, 1, np.where(ts_eq_ask, -1, qr))

# X_print["rule"] = "trade size + quote rule"

# %%
# check_robustness("year_binned")

# %%
# # depth rule p. 14
# dr = np.where(
#     X_print["ask_size_ex"] > X_print["bid_size_ex"],
#     1,
#     np.where(X_print["ask_size_ex"] < X_print["bid_size_ex"], -1, np.nan),
# )

# X_print["buy_sell_predicted"] = dr
# X_print["rule"] = "depth rule"

# %%
# check_robustness("year_binned")

# %%
# TODO: Depth rule + reverse LR (NBBO), Depth rule + reverse LR (NBBO, ISE), ...

# X_print["buy_sell_predicted"] = np.where(ts_eq_bid, 1.0, np.where(ts_eq_ask, -1.0, dr))

# X_print["rule"] = "trade size + depth rule"

# %%
# check_robustness("year_binned")
